# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
from sklearn import linear_model
df = pd.read_csv("car_price.csv")
# print(df)

dummies = pd.get_dummies(df[["Model"]]).astype(int)

# print(dummies)
merged = pd.concat([df,dummies], axis = "columns")
# print(merged)

final = merged.drop(["Car", "Model", "Model_Mercedez Benz C class","Unnamed: 5","Model_Audi A5"],axis = "columns")

Y = final["Sell Price($)"]
X = final.drop("Sell Price($)" , axis = "columns")

print(Y)
print(X)

model = linear_model.LinearRegression()

model.fit(
    X,
    Y
)

print(model.coef_)
print(model.intercept_)

print(model.predict([[69500, 10, 1]])[0])
# print(final)
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64
#     Mileage  Age(yrs)  Model_BMW X5
# 0     69000         6             1
# 1     35000         3             1
# 2     57000         5             1
# 3     22500         2             1
# 4     46000         4             1
# 5     59000         5             0
# 6     52000         5             0
# 7     72000         6             0
# 8     91000         8             0
# 9     67000         6             0
# 10    83000         7             0
# 11    79000         7             0
# 12    59000         5             0
# [-3.18707687e-01 -1.86332151e+03 -5.38759038e+03]
# 57389.55925021878
# 11218.569520563695
# C:\Users\Hp\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
